# %%
"""
# Customer Segmentation Analysis
## Transforming Transaction Data into Strategic Business Insights

This notebook demonstrates a complete customer segmentation pipeline using RFM analysis 
and machine learning clustering techniques.
"""
from segmentation import CustomerSegmentationAnalyzer
import pandas as pd
import matplotlib.pyplot as plt


"""
Data Acquisition & Exploration
Understanding our customer transaction dataset
"""

# Create instance
analyzer = CustomerSegmentationAnalyzer()

# Load and explore data
analyzer.load_data(r'../data/raw/online_retail.csv')
analyzer.explore_data_structure()

"""
Data Preprocessing
Cleaning and preparing data for RFM analysis
"""
analyzer.clean_and_preprocess()

"""
RFM Feature Engineering
Creating Recency, Frequency, and Monetary features
"""
analyzer.calculate_rfm_features()
analyzer.visualize_rfm_distributions()

"""
Customer Segmentation
Using machine learning to identify customer segments
"""
analyzer.scale_rfm_features()
analyzer.find_optimal_clusters(max_k=8)
analyzer.perform_clustering(n_clusters=4)

"""
Business Intelligence
Translating segments into actionable strategies
"""
profiles, descriptions = analyzer.profile_segments()
recommendations = analyzer.business_recommendations()

"""
Business Intelligence
Translating segments into actionable strategies
"""
profiles, descriptions = analyzer.profile_segments()
recommendations = analyzer.business_recommendations()
# Out:
# ✅ Data loaded successfully: (541909, 8)
# ...
# 📊 DATA EXPLORATION
# ...
# Dataset shape: (541909, 8)
#
# Column names:
#   1. InvoiceNo
#   2. StockCode
#   3. Description
#   4. Quantity
#   5. InvoiceDate
#   6. UnitPrice
#   7. CustomerID
#   8. Country
#
# Data types:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object
#
# First few rows:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# ...
